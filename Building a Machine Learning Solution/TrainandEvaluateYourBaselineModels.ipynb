# %% [markdown]
# # 👩‍💻 Train and Evaluate Your Baseline Models
#
# ## 📋 Overview
# Understanding baseline models is crucial in machine learning as they set the foundation for evaluating the efficacy of more complex models. This activity involves training and evaluating a simple baseline model on a dataset of your choice, gaining insights into basic model performance benchmarks. This skill is vital for data scientists and machine learning engineers, as it helps frame expectations and identify potential improvements.
#
# ## 🎯 Learning Outcomes
# By the end of this lab, you will be able to:
# - Choose and prepare a dataset for baseline modeling
# - Train a simple baseline model using appropriate techniques
# - Evaluate baseline model performance using relevant metrics

# %% [markdown]
# ## Task 1: Dataset Selection and Preparation
# You will start by selecting a dataset and preparing it for baseline modeling. This involves basic cleaning, encoding, and data splitting.
#
# ### 💻 Code
# 1. <b>Select Dataset:<b>
#
# <b> Reminder:</b> A number of dataset csv files have been uploaded to this lab environment. Choose one dataset from the following options:
# - Customer Churn (Telecom): `Telco-Customer-Churn.csv`
# - Credit Card Fraud Detection: `creditcard.csv`
# - Bike Sharing Demand Forecasting: `bikeshareday.csv`
# - IMDb Sentiment Analysis (NLP): `IMDB_Dataset.csv`
# - Customer Segmentation (Clustering): `marketing_campaign.csv`
#
# 2. <b>Prepare the Dataset:<b>

# %%
# Load and prepare the dataset

# %% [markdown]
# ### 🔍 Practice
# - Ensure your dataset is clean and properly prepared.
#
# ### ✅ Success Checklist
# - Dataset chosen and imported
# - Categorical data encoded
# - Data scaled appropriately
# - Training and test sets created
#
# ### 💡 Key Points
# - Data preparation is essential for ensuring model effectiveness
# - A proper split maintains data distribution

# %% [markdown]
# ## Task 2: Train and Evaluate Baseline Model
# Train a simple model that aligns with your problem type and evaluate its performance to set a baseline.
#
# ### 💻 Code
# 1. <b>Train Model:<b>

# %%
# Train your model

# %% [markdown]
# 2. <b>Evaluate Model:<b>

# %%
# Evaluate your model

# %% [markdown]
# ### 🔍 Practice
# - Evaluate and compare model performance given the chosen metric.
#
# ### ✅ Success Checklist
# - Model trained correctly
# - Model predictions recorded
# - Evaluation metrics applied and understood

# %% [markdown]
# ## Task 3: Reflection and Insights
# Reflect on the model's performance, strengths, and areas needing improvement.
#
# ### 🔍 Practice
# - Analyze your results and think about:
#     - The realism of your baseline accuracy
#     - How data quality may have impacted the results
#     - Potential feature engineering or dataset enhancements
#
# ### ✅ Success Checklist
# - Evaluation results analyzed
# - Practical insights gained about baseline model performance

# %% [markdown]
# ## ❗ Common Mistakes to Avoid
# - Ignoring data scaling and encoding, which can affect model performance
# - Overlooking a balanced train-test split, leading to skewed evaluation metrics

# %% [markdown]
# ## 📚 Exemplar Solution
# Below is an exemplar solution for the given tasks. Note that this is a simplified high level exemplar solution, and may not be exact depending on the dataset you are choosing to work with.

# %% [markdown]
# <details>
#
# <summary><strong>Click HERE to see a reference solution</strong></summary>
#
# ```python
# # TASK 1
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
#
# # Load dataset
# data = pd.read_csv('your_dataset.csv')  # Modify path as necessary
#
# # Note: Preprocessing steps may be required and will be unique depending on the dataset and model you are using
# # In this case we are simplifying our example by only looking at numeric variables
#
# # Basic cleaning
# data.dropna(inplace=True)
#
# # Separate target
# y = data['target']
# X = data.drop('target', axis=1)
#
# # Encoding and Scaling
# X = pd.get_dummies(X, drop_first=True)
# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X)
#
# # Split the data
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
#
# # TASK 2
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score
#
# # Train Model
# model = LogisticRegression()
# model.fit(X_train, y_train)
#
# # Evaluate
# y_pred = model.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# print(f'Baseline Model Accuracy: {accuracy}')
# ```

# %% [markdown]
# ## 🚀 Next Steps
# Reflect on the strengths and limitations discovered through training baseline models. In the next module, consider how to enhance these models with advanced techniques such as feature engineering or complex algorithms.
